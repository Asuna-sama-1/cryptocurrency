# %% [markdown]
# ### Web Scraping Cryto prices

# %%
pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
import requests 
import pandas as pd
import json
import time

# %%
Date=[]
Marketcap=[]
Volume=[]
open=[]
High=[]
Low=[]
Close=[]

# %%
cmc = requests.get('https://coinmarketcap.com/')
soup = BeautifulSoup(cmc.content,'html.parser')

# %%
print(soup.title)
# Out:
# <title>Cryptocurrency Prices, Charts And Market Capitalizations | CoinMarketCap</title>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no, shrink-to-fit=no" name="viewport"/>
#   <link crossorigin="anonymous" href="https://s2.coinmarketcap.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://s2.coinmarketcap.com" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://s3.coinmarketcap.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://s3.coinmarketcap.com" rel="dns-prefetch"/>
#   <link href="//www.googletagmanager.com" rel="preconnect"/>
#   <link as="font" crossorigin="anonymous" href="https://s2.coinmarketcap.com/static/cloud/fonts/cmc-v2/CMC-V2.woff" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://s2.coinmarketcap.com/static/cloud/fonts/inter/Inter-Regular-new.woff2" rel="preload" type="font/woff2"/>
# ...

# %%
data=soup.find('script', id="__NEXT_DATA__", type="application/json")
data
# Out:
# <script id="__NEXT_DATA__" type="application/json">{"props":{"isServer":true,"initialState":{"app":{"locale":"en-US","theme":"DAY","lang":"en","currency":{"id":2781,"name":"United States Dollar","symbol":"usd","token":"$"},"bottomBannerHeights":{},"browser":{},"window":{"width":0,"height":0,"isNarrowLayout":false},"modal":{"instance":0,"data":{}},"message":""},"calendarEvent":{"listingLatest":{"data":[]},"calendarEventsById":{},"current":{}},"converter":{"isConverting":false,"values":{"from":"","to":"","amount":"","fromLabel":"","toLabel":""},"options":[],"conversions":{},"errors":{}},"cryptocurrency":{"listingLatest":{"page":1,"sort":"rank","sortDirection":"asc","data":[{"id":1,"name":"Bitcoin","symbol":"BTC","slug":"bitcoin","tags":["mineable","pow","sha-256","store-of-value","state-channels","coinbase-ventures-portfolio","three-arrows-capital-portfolio","polychain-capital-portfolio","binance-labs-portfolio","arrington-xrp-capital","blockchain-capital-portfolio","boostvc-portfolio"
# ...

# %%
coin_data=json.loads(data.contents[0])
coin_data
# Out:
# {'appGip': True,
#  'assetPrefix': 'https://s2.coinmarketcap.com',
#  'buildId': '6d3f71af',
#  'customServer': True,
#  'gip': True,
#  'isFallback': False,
#  'page': '/beta',
#  'props': {'initialProps': {'i18nServerInstance': None,
#    'initialI18nStore': {'en': {'common': {},
# ...

# %%
listings=coin_data['props']['initialState']['cryptocurrency']['listingLatest']['data']
listings
# Out:
# [{'ath': 64863.0989077,
#   'atl': 65.52600098,
#   'circulatingSupply': 18725118,
#   'cmcRank': 1,
#   'dateAdded': '2013-04-28T00:00:00.000Z',
#   'hasAdListingButton': True,
#   'hasFilters': False,
#   'high24h': 38231.3391761,
#   'id': 1,
#   'isActive': 1,
#   'isAudited': False,
#   'lastUpdated': '2021-06-02T23:57:02.000Z',
#   'low24h': 35966.30715642,
#   'marketPairCount': 9790,
#   'maxSupply': 21000000,
#   'name': 'Bitcoin',
#   'noLazyLoad': True,
#   'quote': {'BTC': {'dominance': 41.4985,
#     'fullyDilluttedMarketCap': 789763141122.6,
#     'lastUpdated': '2021-06-02T23:57:02.000Z',
#     'marketCap': 18725118,
#     'name': 'BTC',
#     'percentChange1h': 0,
#     'percentChange24h': 0,
#     'percentChange30d': 0,
#     'percentChange60d': 0,
#     'percentChange7d': 0,
#     'percentChange90d': 0,
#     'price': 1,
#     'turnover': 0.04688427,
#     'volume24h': 877913.54541833,
#     'volume30d': 502100223.7385132,
#     'volume7d': 11610640.3532802,
# ...

# %%
coins={}
for i in listings:
  coins[str(i['id'])]= i['slug']

# %%
for i in coins:
  page= requests.get(f'https://coinmarketcap.com/currencies/{coins[i]}/historical-data/?start=20130428&end=20210601')
  soup=BeautifulSoup(page.content,'html.parser')
  data=soup.find('script', id="__NEXT_DATA__", type="application/json")
  historical_data=json.loads(data.contents[0])
  #quotes= historical_data['props']['initialState']['cryptocurrency']['ohlcvHistorical'][i]['quotes']

historical_data
# Out:
# {'appGip': True,
#  'assetPrefix': 'https://s2.coinmarketcap.com',
#  'buildId': '6d3f71af',
#  'customServer': True,
#  'gip': True,
#  'isFallback': False,
#  'page': '/currencies-new',
#  'props': {'initialProps': {'i18nServerInstance': None,
# ...
